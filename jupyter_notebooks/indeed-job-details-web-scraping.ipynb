# %%
from bs4 import BeautifulSoup as bs
from selenium import webdriver
import time, os
import pickle

# %%
# jobs = {}

# %%
indeed_uk_url = "https://uk.indeed.com/viewjob?jk="
indeed_us_url = "https://www.indeed.com/viewjob?jk="

# %%
def scrape(soup, job):
   description = soup.find(id="jobDescriptionText")
   if description:
      job["description"] = description.get_text()
   else:
      time.sleep(20)
      job["description"] = soup.find(id="jobDescriptionText").get_text()

   metadata = soup.find("div", {"class": "jobsearch-JobMetadataHeader-item"})
   if metadata:
      job["metadata"] = metadata.get_text("|")

   title = soup.find("div", {"class": "jobsearch-JobInfoHeader-title-container"})
   if title:
      job["title"] = title.get_text()

   companyInfo = soup.find("div", {"class": "jobsearch-CompanyInfoContainer"})
   if companyInfo:
      job["companyInfo"] = companyInfo.get_text("|")

   return job

# %%
def scrape_details(driver, url, job, job_id):
   driver.get(url)
   soup = bs(driver.page_source)

   try:
      job = scrape(soup, job)
   except Exception as e:
      print(f"Error scraping. Job id: {job_id}")
      return job, (job_id, "scraping", e)

   return job, None

# %%
def scrape_job_details(driver, job_ids, jobs):
   incomplete_scrapes = []
   already_scraped = []

   counter = 0

   deleted = ['b0f82946b85ea228', '9de3cf82db801fdf']

   for job_id in job_ids.keys() :
      if (job_id not in jobs) and (job_id not in deleted):
         job = {}
         job['id'] = job_id

         url = indeed_uk_url + job_id
         try:
            counter += 1
            job, incomplete_scrape = scrape_details(driver, url, job, job_id)
            if incomplete_scrape:
               incomplete_scrapes.append(incomplete_scrape)
            else:
               jobs[job_id] = job
         except Exception as e:
            incomplete_scrapes.append((job_id, "navigating", e))
      else:
         already_scraped.append(job_id)

      # if counter > 3:
      #    break

   driver.quit()
   return jobs, incomplete_scrapes, already_scraped

# %%
# Load data
with open('job_ids.pickle', 'rb') as handle:
   job_ids = pickle.load(handle)

job_ids
# Out:
# {'264f504fa90d856f': None,
#  '5573e1b6447a8af6': None,
#  '41ce545464f94ca7': None,
#  'c461ed010a20c835': None,
#  '1fe7173e0d89af7a': None,
#  'f1b98d776e72be61': None,
#  'ec3849d4dda665c6': None,
#  '278142c7efa8c49a': None,
#  '8e4ebf6f8f6568f8': None,
#  'c8610c368721c0ab': None,
#  '98f78125259351fb': None,
#  '9a36d2355241924b': None,
#  'f11971796d62ded9': None,
#  '1619eda6ee3dcbb0': None,
#  '14a3bb31248f543a': None,
#  'e7d30ae416f248ca': None,
#  '9da03cdc1f38e23e': None,
#  '488bf3e35de656b4': None,
#  '2f632b10cfb5bf93': None,
#  '62f378db55687030': None,
#  '561da9499d1ccc7f': None,
#  '7a7c63c336e285aa': None,
#  'e7362c51c4671308': None,
#  '0edc5a7b195f5c79': None,
#  '1e75c64559d233ac': None,
#  '7d06f30f27ef44b9': None,
#  'de7ad63840a4e83f': None,
#  'af9df3033edaa0ad': None,
#  '14cc06ce96650681': None,
#  '4b91fb225034dbcd': None,
#  'c727cfe03669a9fe': None,
#  'a1bc538f4c7ea3e3': None,
#  '70332396f3c8444b': None,
#  '5886011685afc18c': None,
#  '3c5304799384cdf7': None,
#  'd201512b8f8050e7': None,
#  '81fa085584b780c0': None,
#  'b9674db94a63aa09': None,
#  '6d3f07e5f165cbbe': None,
#  '3c604da224d17eaa': None,
#  '3a3962e851fcabfd': None,
#  'bc4ba6a5bcbd4e1d': None,
#  '81596e087bc722e1': None,
#  '660fd2b4bb007966': None,
#  '563f7c6c8761c9a2': None,
#  '0bc9a0034bb799fb': None,
#  'c70b2796aa6b902a': None,
#  '5ab88ea54a966581': None,
#  'ac49b59e8a82583e': None,
#  'a94f4d54358cb761': None,
#  '28d4b302ed4e7a8f': None,
#  'faf18cde163cb052': None,
#  '11b279affdc15fa6': None,
#  '402a961d9343589c': None,
#  '4e2cec138ff8c10c': None,
#  'b4e724c9d45bb6d7': None,
#  '71a03a423e2d00ec': None,
#  'f8a3b3c97584a2f1': None,
#  '80ba1147518747d1': None,
#  'ee6d93fa4db1286b': None,
#  'ad36fa1497c44114': None,
#  '3cdc735c12c5b93e': None,
#  '841461e2b3d8b311': None,
#  '03d73361ba1952c6': None,
#  '5090778a3aa8615a': None,
#  '24da8ddbf643edf5': None,
#  'f917a2dda63687fb': None,
#  '53115722af79a224': None,
#  '5add8e0c22dc6a90': None,
#  'cc4623fad79aaed5': None,
#  'c0d5f5d4aa7c7512': None,
#  '1da6e1b1396fb493': None,
#  '7588b22af9272a7a': None,
#  'b0f82946b85ea228': None,
#  'e443cd2cc7418db6': None,
#  'aa2ae1d0a4d94913': None,
#  '431c020da576e8ef': None,
#  'f6708e279e3710c8': None,
#  '1629aa16b283b62a': None,
#  'f855218712f1312d': None,
#  'b9aaf6bc697f4707': None,
#  'de0602394c660b79': None,
#  '5f2ab69610d80c67': None,
#  'e335735381987b93': None,
#  '05562bb9640e348f': None,
#  'fcf740145428744d': None,
#  '411023f45dd76c85': None,
#  'afa774a22f9fcecd': None,
#  'bf1b30ad6c85da78': None,
#  '913931eda481b785': None,
#  '1b7bc1731f281dfa': None,
#  '37168cbe56575a1b': None,
#  '2e096edc03c41d1f': None,
#  'c31e26f758982465': None,
#  '8301333f7a7b1b08': None,
#  '9da21f9d62d065b2': None,
#  '18fc25de7dbb1a78': None,
#  'a3156543aea30ca7': None,
#  'c0511da267cd13f7': None,
#  'bd55febe65fe1000': None,
#  '9d3eef7436c98f70': None,
#  '3f67555fde34621d': None,
#  '718635a04e11ed5e': None,
#  'db78004d47530886': None,
#  '1f43d5d69c62997c': None,
#  'ade7700e5a7449d2': None,
#  '18e0525056cc5620': None,
#  '19a3344773721ea3': None,
#  'd8c66de13ad01062': None,
#  'c8046526596798e5': None,
#  '8e1c35401543ce71': None,
#  'c488d77ef75f0ec4': None,
#  '8efae16f6455bb94': None,
#  '4336fdbef2657586': None,
#  'd16b3c233fc98073': None,
#  '51ebdee8bf536599': None,
#  '87b1c0ef5735bc2c': None,
#  '19946406d21a9046': None,
#  '975d081de0924d70': None,
#  'c3cb52150b0d7500': None,
#  'dec6ef1330f945bb': None,
#  'ebced99add800409': None,
#  '026a946613be0a47': None,
#  'f33d95d36e4e74e5': None,
#  'afdb4d7db7f53b54': None,
#  '1972c1c50c935442': None,
#  '921deb009ca5786a': None,
#  'd6c055db46a5ca79': None,
#  '6a0891740b47b730': None,
#  'acd6d47c8efdfe0e': None,
#  '1998e237baca21e9': None,
#  'e9ed5365f5222ed5': None,
#  '1f2739ac545d24af': None,
#  'dc7986d1a346853c': None,
#  'bdaf9e3f84b09d12': None,
#  '83ecd37d0980dcab': None,
#  'c91be41078a88731': None,
#  '843b48c2eb7b4936': None,
#  '9de3cf82db801fdf': None,
#  '55c18aeec1796780': None,
#  '9ccf7cf090604d68': None,
#  '5036867b4b85eb7f': None,
#  '7c2052704a07e045': None,
#  '832f1abb54e1683d': None,
#  '739879dd1e0d089a': None,
#  'c15b377b26856670': None,
#  '8d948900a8824ba0': None,
#  '9e6045d4d4d03a88': None,
#  '53ca1d76767864e7': None,
#  'a96992601c109ea1': None,
#  '19a73e971e9021fe': None,
#  '5a84ff72d21cbcce': None,
#  '531d5eab84df96fe': None,
#  '575bddc8fd4489d7': None,
#  '5cb0d4d94bdd6470': None,
#  'aaa5b2925698cfdf': None,
#  '40d1d4bb5b2a7f0e': None,
#  '0cf30d99098f568d': None,
#  'a3dc30a5b77da498': None,
#  '7a45d72d4bfe629c': None,
#  'b31e6f8753009388': None,
#  '24e2fd89e44825e6': None,
#  'aea879579a5a8130': None,
#  '7b9019baac321e56': None,
#  'c910c4f165ab97d1': None,
#  '8297601b2a0be145': None,
#  '68504327d798223c': None,
#  'aad8ce79a16e8910': None,
#  '81361cf15857c1e4': None,
#  'c48b21af3c226bcc': None,
#  'ccd121c2924a11e2': None,
#  '6993bbcf05b3a75d': None,
#  '4d1d27e9148ae8f9': None,
#  'b390306bb30b8754': None,
#  '7ba5d88e0c23343f': None,
#  'c8578e945a83ef66': None,
#  'a8e76654595d9fde': None,
#  '08fe5af25719f611': None,
#  '8d04d136ca506c79': None,
#  '6b09ddd8c8759fe8': None,
#  'eb5538117ce4e88f': None,
#  '58db161a5a3ba0aa': None,
#  'da50f0200ebf2a82': None,
#  'b3ca17a93bc59859': None,
#  'a7b790e829155678': None,
#  '998dcd8efcedd8b4': None,
#  '63541bd2e3fb5953': None,
#  '22fe0ee614a5ab2d': None,
#  '91a6bdaad8010cbc': None,
#  '33afc3784ddf10e4': None,
#  '8fce3a367bf429f8': None,
#  '19621b55a6721d3b': None,
#  'ad5ab412b93c4a21': None,
#  '537ca5a69a83e1b7': None,
#  'f8f1f57cec8f60c8': None,
#  '8ce74f9367afda81': None,
#  '85dad98955fea8db': None,
#  'b0fea4b5c74439d0': None,
#  'f3a81551f56b0cd0': None,
#  'e896c3fa16b9cabb': None,
#  'e562346b576e677a': None,
#  '2ae53d5e5af7ba63': None,
#  'a9b2269ce04ee732': None,
#  '615d0bca7c22bd93': None,
#  'bb18693b7268431f': None,
#  'fa2103b6379e0e71': None,
#  '6d9546d626d2d1f4': None,
#  'd654b91604598e27': None,
#  '523c7adf3049b392': None,
#  'df7fa4ed791e4fbe': None,
#  '07e92d803e554ba1': None,
#  '6cc7825552129760': None,
#  '106039cbe93005f1': None,
#  'bde130c9952fd766': None,
#  '8d74ef43e0b826f0': None,
#  '6a98da6bc2a46121': None,
#  '0cbf5a2ee60798e5': None,
#  'd7f6b574d5cd7726': None,
#  'e4c72317934dc267': None,
#  'b79f43e5a22a579a': None,
#  'be8bdc090bc10cce': None,
#  'ba62e77b2b063aa4': None,
#  '4f28b781d13b85e5': None,
#  'd08d721c65a779b7': None,
#  'cb9ea43259a721c7': None,
#  '27e8b7737b1ad482': None,
#  'b0c9657c0d0c1bdb': None,
#  'a87bf2999d83ed72': None,
#  '91d28f8c8fc52d25': None,
#  '8d8692e8c6b1784c': None,
#  'c8eb1313968172b1': None,
#  '0ebda6d76b309bea': None,
#  '562cc390e4e7243b': None,
#  'ae72fa071664d9c6': None,
#  '92c7445c9e95b2ef': None,
#  'c3302803a9fdb81b': None,
#  '33ae52e7138fefd2': None,
#  '4237f32f21088875': None,
#  '0aafae2848682fe0': None,
#  '1f10da8202bb6562': None,
#  '05c25c8b224291de': None,
#  '5ddae4001cb925a7': None,
#  '41fc6c9af03f3e7e': None,
#  '093b49adffe365e9': None,
#  '7fd40b24b80a4870': None,
#  '8596de9cc18e85cc': None,
#  'ad69983b4a978518': None,
#  'b49471802b099cc9': None,
#  '198445b76cc800a5': None,
#  '670f4111f3cccc00': None,
#  'f4d1586c7e6024e1': None,
#  'f154763a6bda5191': None,
#  '837f01b839a4c17d': None,
#  'e848e51ac83f9634': None,
#  '51599f7554becc60': None,
#  'a0fdd28e26dae14b': None,
#  'f8842b5f3dfbdba2': None,
#  '452a0034b6d8acf0': None,
#  '2b25dc33075f6b63': None,
#  '4d5a6de605dc6169': None,
#  '081fd3dcbdc2a0ae': None,
#  '2da25210ca78df6b': None,
#  '88a39aaeea593d53': None,
#  '19bfffe168dedfcf': None,
#  '3314f5cb31ea128d': None,
#  'd29196b12dc5ebf4': None,
#  'b1eb64daeaeac47d': None,
#  'cef9d6ff61c0c348': None,
#  '119a1603173fc943': None,
#  '8b51bbf26c87397a': None,
#  'fd59d828e60f4769': None,
#  '873fd8327e5436ea': None,
#  'b55404440fd5e0a1': None,
#  '60236563be2674bf': None,
#  '73e50ccd2fb91bc8': None,
#  '80bcc78f72a43117': None,
#  'd650704f2dd71f64': None,
#  '3ea48cb0d172ae24': None,
#  '3d4e6d3144dfbfe3': None,
#  'd1a12f6813185507': None,
#  '84bf9385bce04fe0': None,
#  '7ec8782ae7432e26': None,
#  'e6a698065b1f23f1': None,
#  '49be161b2eb5905f': None,
#  '6304ab449d9f665a': None,
#  '8246dfb15ef46da1': None,
#  '2bc7fe210ccc0cec': None,
#  '7ba7a9a9aa27844c': None,
#  '679837c98d24c4fe': None,
#  '4c1df497a1e9f9ee': None,
#  'd25ad1de490f2879': None,
#  '738087a3120dc076': None,
#  'bb346ac5a325d1a6': None,
#  'fc425918421dee3b': None,
#  '35c6efd1aa7626e7': None,
#  '8b36f9c2e074f492': None,
#  'd960a8ad41d0155f': None,
#  'f11441043cb87066': None,
#  '7eee7a88a356ceff': None,
#  '5aa7f52560d5ddbf': None,
#  '77016b918975fdab': None,
#  '210ee5824998db75': None,
#  '7bbfdb9b598d1aa9': None,
#  'd641e05147a73833': None,
#  '0dc8f9e985861b3b': None,
#  'e7eeeef35e86e341': None,
#  'ae6f2e35fade46c2': None,
#  '9ac10a207e4f8e28': None,
#  '30c3d9a7bbe360fd': None,
#  '4d1f2e56352f2c30': None,
#  '4b1b3ed81be18816': None,
#  'ce301e1e61455c46': None,
#  'e0119a3cdfff95b8': None,
#  '7ef967ea4c392ce2': None,
#  '86d430cba60bf524': None,
#  '27344cc32441eb1d': None,
#  '664380b84cf21c54': None,
#  '44409a611e9aa70e': None,
#  '9d5f9ddee8935ad3': None,
#  '4d954ce63f2662a2': None,
#  'dc3c23821e500bc8': None,
#  '7f47b75a1a8dfb20': None,
#  '63855f2c106d6d6f': None,
#  '8bad546bf985f1fc': None,
#  'fb5424ca8aedf2fa': None,
#  'e1e86abf842cb8cd': None,
#  'f629b54efa7cb0d1': None,
#  '99ab79373ec23665': None,
#  'cd2cf93bdd8f6f1a': None,
#  'dfa29bbeaaf53af9': None,
#  '88827a8e6fb68acd': None,
#  '009cd9b7aedc05a8': None,
#  'f3791a2c57774d96': None,
#  'd19751ee936a2cb1': None,
#  '1d59ba03cb8916cd': None,
#  '9d519cd265c9daf1': None,
#  'd160b628d1729576': None,
#  '9dbd52ad8388c38e': None,
#  '5aad6e8f0706dad7': None,
#  '002b642733462026': None,
#  '83002b5c2efc3e64': None,
#  '6c636f53b7c5e21e': None,
#  '24a22577cc0bdd26': None,
#  'f35455dc0cfa30e5': None,
#  'befc652e66855b20': None,
#  '9900e15138ebeeef': None,
#  'f5e86078c5559e08': None,
#  '89a0578c1f858035': None,
#  '10d76b1832a637de': None,
#  '55d4bac31c7185bd': None,
#  '28d2fb7b92e47040': None,
#  'cb98a1baf4c05e8d': None,
#  '842c3263827f15ec': None,
#  '1432a3f7f9181574': None,
#  'd30022652d9c0604': None,
#  '126abd2d8e9f21f8': None,
#  'd40f07b1a03c2a99': None,
#  '5eeb98fd92727909': None,
#  'fdb82d70b4dd0a2a': None,
#  '765a317f312e9790': None,
#  '47c72ef0ae07e2ed': None,
#  '6084556df15ed096': None,
#  '96253928c6a4312b': None,
#  '56c517fbb2ff59c6': None,
#  'df3908f9fbf222ae': None,
#  '4a90fbc72e50f8c0': None,
#  '8ceef1354d834829': None,
#  '40908e2e02d24fb7': None,
#  'e44b71d3e443ed12': None,
#  '204f9c4e6a687707': None,
#  '389d8b0ec0c36199': None,
#  '857126228592da79': None,
#  '5a4e1653fe71a2f2': None,
#  '7d2c3bbed3bd0e31': None,
#  'd559379151f2a975': None,
#  '2a297f65a8c0be46': None,
#  '395dedbfb84df52c': None,
#  'fef03f20f4bce0fe': None,
#  'e8c4c94eb41b01ad': None,
#  'df5557a1917cc416': None,
#  'd04390719d88d18e': None,
#  '3187d680f4876530': None,
#  'b4a8ea101c97ed0a': None,
#  '08e8b46c21c3fc0c': None,
#  '6b58cebdc25755b6': None,
#  '64572ef002b5fe15': None,
#  'aa1fb7524a7df30e': None,
#  '72845e843b8e1c95': None,
#  'b6024c69f12e8dd0': None,
#  '39b8ca466cebd1c9': None,
#  'b0e0123b63ab41ca': None,
#  '48c8eb992a2d923f': None,
#  '5b4ec176f36201b0': None,
#  'a5768bd661b496da': None,
#  '9f6d32c77368d4ef': None,
#  '4e995b00d3fec6b7': None,
#  'bfd754a885091106': None,
#  '12dd715fccf84501': None,
#  'e8b33003f88eda34': None,
#  '68eeaf3b6960c0c6': None,
#  '441d0aeba3fcbb35': None,
#  '509f0ab07e598c93': None,
#  'a3ae4724b83acdbd': None,
#  '0dfd32a595ea5f43': None,
#  '96f960313c58d972': None,
#  '4efc0d943cab99e3': None,
#  'f7b0ddeb1800f34f': None,
#  '5a7be03347cb8c46': None,
#  '8e0d8f88008dcb41': None,
#  '31b8a999327974fd': None,
#  'b73719a4ef2a3383': None,
#  '6bfd596364d385a9': None,
#  'b280f073f2de3a01': None,
#  'b381c50d3a4b94c5': None,
#  '5a3979cda328b11b': None,
#  '82c679a84d6c1ac9': None,
#  '4fd626dd65905fd2': None,
#  'bdb4f53005b0491c': None,
#  '89bffef3e6a966bd': None,
#  'cec188ac669b18cb': None,
#  '0d7f15a008c47a44': None,
#  '772f368dcbefa8bc': None,
#  '3d5ab59f8735ad94': None,
#  '63a1d24bbdcc1cdb': None,
#  '8b979985293f6430': None,
#  '23b1fd9a90bba51d': None,
#  'a941553de2f22cfe': None,
#  '968d90c937d40c4e': None,
#  'aad93171fefe4a44': None,
#  'f494d612d32a9897': None,
#  '1638acd352b11e96': None,
#  'ff6430d8f7a58324': None,
#  '59fae3d343fb938b': None,
#  'e8265f66bb4869d2': None,
#  '127b35eba2779eaf': None,
#  'c8dc98482c570154': None,
#  '093445b18afd74bf': None,
#  'e244e6332d11a176': None,
#  '1c51a016c859d14c': None,
#  'ad1a7832c11d9a0d': None,
#  '1a3a27ba37992dc7': None,
#  '9f2cc4a726b259d5': None,
#  '0be48bb6a7ec051c': None,
#  '8f8b78def7ec7c6f': None,
#  'db785b44a3aeb45b': None,
#  'a934743071e8a121': None,
#  'a07ad709857710c2': None,
#  '0186a0d92e0b3859': None,
#  '4aff8c8544acfc61': None,
#  'e7b8a49970f66a11': None,
#  '368738223ecc3857': None,
#  '22fea4c2dcf38c4e': None,
#  '76e0b185dd4645da': None,
#  'cf8d66cc74f03468': None,
#  'da99ce0b13664ad7': None,
#  '705c967fa7b8b827': None,
#  '11662bfc2ee3d601': None,
#  'f9894133a3a58200': None,
#  'fc01eb923b18e45f': None,
#  '28dd64780206d387': None,
#  '07c31aaa622a74b3': None,
#  '53c8b46b16b85529': None,
#  '8067dc017aea7082': None,
#  '6a7295ab37cf32cf': None,
#  '4ebab22d6288f219': None,
#  'a2ad7a7575940c9e': None,
#  'a5ea3408ebafe917': None,
#  '4a014e715cefd543': None,
#  'b6251e27ea9c0c04': None,
#  'e66a0ab3210372a5': None,
#  '3bd9c52907e1d156': None,
#  '1b9350d23fdd7e2e': None,
#  '6f1278aa3b99fb74': None,
#  'cb35202243468f28': None,
#  '5a4fd38de4ed8ff9': None,
#  'be87bf52274b7ab4': None,
#  '116d78b286dbd52b': None,
#  '4e4da1419ce44ea0': None,
#  '41480bd4da937b40': None,
#  '97f8a0132154c9a1': None,
#  '683f4afe4aa24a75': None,
#  '82fee018377d7ab3': None,
#  '5af105088d584972': None,
#  '05c85fc574019e3d': None,
#  'e2a532db78d08c76': None,
#  '74edc05ad8ae5b31': None,
#  '221dc6b0b6f162b6': None,
#  'acb3e1226a9b6b8b': None,
#  '3c5f5897fe13cc6d': None,
#  '2671b0d51000d4f5': None,
#  'b887b445da1a4391': None,
#  'cb713156a3ee8404': None,
#  'c3468c2108db4979': None,
#  'ba4997e71efabfb7': None,
#  '112a7301e6c40ec5': None,
#  'ed8b4d1db68122fd': None,
#  '7d3f54a1eec05907': None,
#  '7e46487ddfd3895c': None,
#  '53f9e2fe65f0c887': None,
#  'adfb78373f9df155': None,
#  'e8d1c27a06785563': None,
#  'd57758f0f1df1a6b': None,
#  'b2e014e0701b9ab3': None,
#  '9aa0cb156577235d': None,
#  '97218af4c4820ffb': None,
#  '2943108fd41a847d': None,
#  '836bef20e756318f': None,
#  'eaba89a648d0c58c': None,
#  'c2e3b298c94a68b7': None,
#  'f22bd03db4a91ac6': None,
#  'cfb808f6fff38cf0': None,
#  '2cc917488c41b493': None,
#  'c152cfefb8489d3e': None,
#  'ce9782e1ff949e8e': None,
#  '4ee1ae9ddd37c2e7': None,
#  'ead428436879efad': None,
#  '84f7ae3c8648d5a5': None,
#  '44ef839f4aeeb6a4': None,
#  'b6158bc8135d022c': None,
#  '3828b425eec158a1': None,
#  '1a813e5880176a8f': None,
#  'b5db49155c074401': None,
#  '0a39764150e0780e': None,
#  '4213fa89ce5ea5f7': None,
#  'bf10e9fa14af51e4': None,
#  '960383f3bf3e484c': None,
#  '0d32c95caac23bd3': None,
#  '58adc88e9e659750': None,
#  'fa8d4a7eb17d96e0': None,
#  'bc8943250056fe4b': None,
#  '13fc83f3e3ce2fa4': None,
#  'bec9329355ccc963': None,
#  '425392576e47c4bc': None,
#  '1f1bc53c0dfe58a9': None,
#  '9bbadbd3da6c65c4': None,
#  '6e47100887a9379e': None,
#  '3de6c74f1784e017': None,
#  '089c74db2db65b72': None,
#  '21195d8ca2345ffb': None,
#  'c0952e299199d419': None,
#  '94ebed1273c0fe68': None,
#  '3ec3b38373dfdea6': None,
#  '1a6f9b72dacc1ab4': None,
#  'ae10434f2362a03b': None,
#  'e64c5db9112fe6c3': None,
#  'c3a0a4336475f802': None,
#  '4f1f1a3e6774f5e6': None,
#  'd0f10ed9011c168a': None,
#  '52209eae9c5f001c': None,
#  'afb3d92118f40604': None,
#  '8346a73715343ce5': None,
#  'd45e6b8090f32272': None,
#  '7ce5086c180e610e': None,
#  '5f09f37f6e3da49d': None,
#  'da4265addfbdc619': None,
#  'd103cbf412b11ab4': None,
#  'b2d156dac587c730': None,
#  '74a35620924e5a05': None,
#  '1b1a29d6dad9af8d': None,
#  'aed0b0245a86be30': None,
#  '032888037e217bd5': None,
#  '9d9549e7d17bbd27': None,
#  '57ad9afcac2d9191': None,
#  '0c3af0401a159ef9': None,
#  'fe101a0a083a0c89': None,
#  'c188d06623aed0d3': None,
#  '9e14753687bc9d0f': None,
#  '43c0c9c4fd1f90fc': None,
#  'c03fee661bac9431': None,
#  'ab439a1fbb95bf97': None,
#  'dc6c6978745bc509': None,
#  '648ea219d7e3d4ff': None,
#  '79c1b7d443aa6d5e': None,
#  'c7f5f6247ada2f71': None,
#  '1b97a916c9d65b2a': None,
#  '4c3e6c4391307ec0': None,
#  '22f38240e4bb1e8d': None,
#  '04b5193db5e8a901': None,
#  'c3f3dc3e37652633': None,
#  'ec920e43123ea232': None,
#  '5c44dc42c5045ff5': None,
#  '14987becb757c6b9': None,
#  '506d5d7ef0ac7c53': None,
#  'e42e7fce5aaf2049': None,
#  '60fa453d68aca830': None,
#  'f8ce87dd97228863': None,
#  '4f736a337ad5137b': None,
#  '34ea153d284198d8': None,
#  '93464bf0b81f3f2c': None,
#  '5147807f97262658': None,
#  'e74f27b8d7300660': None,
#  'cec8f1321136863c': None,
#  '8837c81dc97b5d14': None,
#  '3dc47c60c0bf5a4a': None,
#  'a9a57901ffc154fe': None,
#  '0eeb27c40f139919': None,
#  '322f1d09eeea380a': None,
#  'b0008b387490d057': None,
#  '1bfa4b466a566959': None,
#  '152d3f0e10d0e1dc': None,
#  '0fb297cc2191df3b': None,
#  '9aade3b53969d6d3': None,
#  '972400f92e58cfbe': None,
#  '13d399fe8af2bfca': None,
#  'dc8c11290212aec5': None,
#  'a84c359368d4bf76': None,
#  '25b73e5be22f6f71': None,
#  '3dbd0698228b8a01': None,
#  '1e7c6703329f5d17': None,
#  '97c2e17a393fa3e4': None,
#  '6772a31ed1132c61': None,
#  'f98737d114712a2b': None,
#  '8a2499edf3537ed3': None,
#  '8559534d87a73b1b': None,
#  'e03f26755ef68608': None,
#  'b76b8725cff2dfa5': None,
#  '0f5965da90cfdba7': None,
#  'bd5c572146b0f8f3': None,
#  '49b5a27b2b6f6c7c': None,
#  '9e3b061712c361d0': None,
#  'a798305716559dbf': None,
#  'e21f8e25241bf90f': None,
#  'd7595c8b6cca24f5': None,
#  'd6ec9b9ed536a786': None,
#  '0da9e1520b7ac73a': None,
#  '24b8aee2aa405b80': None,
#  'f6a27ae34c6b77a2': None,
#  '1293b9a6b378fa5e': None,
#  '99ad94c8a4f1ab03': None,
#  '6d62ab69cf2bead6': None,
#  'edf1f9a1a5bc49c1': None,
#  '7446b241063b6261': None,
#  'f5982da80f9c4ba8': None,
#  '186e5b2ec000b1ef': None,
#  'b62ab962f2ea3e60': None,
#  '06e5302357c791c5': None,
#  'fda503f83dd4a9c5': None,
#  '7a6e56d07e657489': None,
#  '5dc1ea628781aa17': None,
#  'cd2d58bda138d9bc': None,
#  'ff146d21e7758cb2': None,
#  '196da4e235bf5950': None,
#  '055179f0d7045e1f': None,
#  '07472ca4d96d78bf': None,
#  'e3593998d4e0f768': None,
#  '73405e9f3a58dbe2': None,
#  '07f008a54169d23c': None,
#  '32a73197ffb10315': None,
#  '1cef50c3fa39334a': None,
#  'f091cb3818c1fba3': None,
#  '719cd96d7af9c0cd': None,
#  '929607895276d008': None,
#  '717a6eb8647ba6d7': None,
#  '17d6495982c2b3dc': None,
#  '6b863943966cd231': None,
#  '9f47d1a99bea8203': None,
#  'c319cf73920ff583': None,
#  '43c2c895d3495a69': None,
#  'fc6b72c7d8b5db56': None,
#  'b45c4bd808200007': None,
#  '2a0a0b479dea01aa': None,
#  'd69e216d4563fd70': None,
#  '68661f0261320ee3': None,
#  'fa5d26478366852c': None,
#  'b31465d3d72dc364': None,
#  '965554995a44d3de': None,
#  '8043af363a550dbe': None,
#  'f8ceac26d6eed1de': None,
#  'b3e4f3ef951ae00e': None,
#  '8111c8d557522adc': None,
#  '5ccf8e4ea691b2f5': None,
#  '4b8d79e73e15d6a6': None,
#  'c47538489e5198c6': None,
#  '0df4008cb782d616': None,
#  '693f9b2087518109': None,
#  '1a16821bcfd31db0': None,
#  '9cef3f759cdd5ad7': None,
#  '4c45b1172a434412': None,
#  'a593e2fe68bca931': None,
#  'ca6381158a0263b3': None,
#  '6c51de2e7d187249': None,
#  'd92a587131b143dc': None,
#  '745a58a651307865': None,
#  '8c6197943b3ddc5b': None,
#  '90f155e63cde1dc3': None,
#  'e392d83cec57f23e': None,
#  '79e0a6833237740b': None,
#  '23f924091a5a572a': None,
#  '98b5d932260473ce': None,
#  'be7be54e7ec93ebe': None,
#  'd60f251ca690c7f3': None,
#  '2dfd7bd713cfb5f3': None,
#  '7949803937c0060b': None,
#  '9eadccb8fedf3b82': None,
#  'dfb5dc881d594479': None,
#  '74d76ee36d91590f': None,
#  'c006c15145cdce21': None,
#  '769bdbaf7528a07d': None,
#  'e3168cf104233d47': None,
#  '30744322df5c85db': None,
#  'e26f8af02b52b1d1': None,
#  'f540fa0fb176335e': None,
#  '10711a265f63adec': None,
#  '9e3227ec5d5e087d': None,
#  'f0e1173b9be0063d': None,
#  'a0373ee68e9e04a1': None,
#  '51ad87c8461d6237': None,
#  '58698459c4c5649b': None,
#  'd8f7a0e3ea09fd37': None,
#  '1752261e984bccbd': None,
#  '3c2a187a09736a40': None,
#  'd932954a00eb1880': None,
#  'b1946150b3657a62': None,
#  '18971fa22d892a83': None,
#  '41584669bb038c8b': None,
#  '7138cf4d176f1034': None,
#  '93aa3b150a054d03': None}

# %%
len(job_ids)
# Out:
# 717

# %%
chromedriver = "/Users/william.bell/opt/anaconda3/envs/metis/lib/python3.8/site-packages/chromedriver_binary/chromedriver"
os.environ["webdriver.chrome.driver"] = chromedriver
driver = webdriver.Chrome(chromedriver)
driver.implicitly_wait(3)

# %%
start = time.time()
cars, incomplete_scrapes, already_scraped = scrape_job_details(driver, job_ids, jobs)
end = time.time()
print(f"Time taken: {end - start}" )
# Out:
# Time taken: 26.270166873931885

# %%
incomplete_scrapes
# Out:
# []

# %%
len(incomplete_scrapes)
# Out:
# 0

# %%
len(already_scraped)
# Out:
# 669

# %%
len(jobs)
# Out:
# 715

# %%
jobs
# Out:
# {'264f504fa90d856f': {'id': '264f504fa90d856f',
#   'description': 'Live shows make us feel good. They’re a time to hang with our friends, discover new artists or lose ourselves on a dancefloor. We’re on a mission to bring all of this to more fans, more often – and that’s where you come in.\nWe’re looking for a Data Scientist to join our Data Science teamand help build products to improve the experience of fans, partners and stakeholders.\nAt DICE, you’ll be part of the company that’s redefining live entertainment. It’s a place where you can be yourself, influence the culture, and create work that you’re proud of.\n\nAbout the role:\nIn close collaboration with our Data Analytics team, Project Managers and Designers, you will perform internal analysis of key strategic initiatives across multiple departments. Your insight and recommendations will be converted into data products that will reinforce internal tooling and the predictive abilities of the team as a whole.\nAlongside forming reports for stakeholders, you will be creating and maintaining new algorithmic capabilities in areas such as churn modelling, survival analysis, user segmentation and personalisation.\n\nYou’ll be:\nPerforming analysis on large sets of data to extract impactful insights on user behaviour that will help drive product and design decisions\nConducting hands-on modelling/advanced analytics retrieving, and compiling and analysing large volumes of data into distilled actionable information that answers critical questions\nMaintaining and improving algorithmic capabilities in areas such as price optimisation, inventory management and performance analysis\nDefining, building and deploying algorithmic capabilities that span multiple functions within the business\nReporting and communicating the results and use cases for your analysis and solutions\n\nYou are:\nA fan of music and culture\nPassionate, humble and talented\nActively responsible\nAn extraordinary team player\n\nYou’ll need:\nKnow-how to understand and tackle loosely defined problems and come up with relevant answers and impactful insights\nThe ability to explain complex concepts well, and move decisions forward in collaboration with your peers\nExperience with writing code in production environments in either python or R\nProficiency with SQL, and the ability to navigate large and complex data stores\nTo thrive in a fast-paced, high-growth, entrepreneurial environment where quality, innovation, speed of decision-making and execution are critical to organisational success\nCommitment to develop subject matter expertise on company data and the ability to develop analyses to drive actionable insights\n\nAbout DICE:\nOur teams work from London, New York, Los Angeles, Barcelona, Paris and Milan. We’re building products that will revolutionise the industry for fans, artists and venues – and we’re growing fast. Read about our latest Series C funding and what’s next for DICE.\nWe know that having a variety of perspectives makes us a better company – it’s why we strongly encourage members of underrepresented communities to apply. Find out how we’re creating a more diverse, equitable and inclusive DICE.\nUnlimited Holiday\nPension\nHealthcare\nOur process usually involves a quick chat on the phone, a portfolio review and/ or task, and a couple of interviews where you’ll meet the people you’ll work with. We’ll keep you fully informed along the way.\nFor information on how we use your data, please view our Candidate Privacy Policy.\nPython, SQLPython, R, SQL',
#   'metadata': '£50,000 - £70,000 a year| -  |Permanent',
#   'title': 'Data Scientist',
#   'companyInfo': 'DICE|London'},
#  '5573e1b6447a8af6': {'id': '5573e1b6447a8af6',
#   'description': 'At Burberry, we believe creativity opens spaces. Our purpose is to unlock the power of imagination to push boundaries and open new possibilities for our people, our customers and our communities. This is the core belief that has guided Burberry since it was founded in 1856 and is central to how we operate as a company today.\nWe aim to provide an environment for creative minds from different backgrounds to thrive, bringing a wide range of skills and experiences to everything we do. As a purposeful, values-driven brand, we are committed to being a force for good in the world as well, creating the next generation of sustainable luxury for customers, driving industry change and championing our communities.\n\nJOB PURPOSE\n\nBurberry is making a major investment in expanding our data and analytics capability. Over the last few years, we have created a global omni-channel single customer view, built an outstanding and modern analytics platform, and developed a highly effective analytics and data science team. We’re now building on these foundations to drive and embed data-inspired decision making across Burberry.\n\nWe are recruiting Data Scientists to join our fast-expanding data science team and be part of one of our core strategic functions across:\nPersonalisation, Precision Marketing & Customer Journeys: Using advanced modelling techniques to uncover our customers’ behaviours, preferences, and intent and deliver targeted and personalised experiences across all customer touchpoints\nCommercial & Marketing Optimisation: Using state-of-the art statistical models to measure the impact of our initiatives and inform our decision making in prioritising investments across our retail, technology, and media portfolios.\n\nAs a Data Scientist, you will be accountable for building and deploying robust statistical and machine learning models, exploring a wide range of new data sources, and generating reliable and actionable insights and recommendations.\nAre you a data scientist, or a recent graduate with an advanced degree in a quantitative field, and with a proven record of using data, statistical modelling, machine learning and deep learning techniques to solve business problems and drive business value? If so, we’d love to hear from you.\nRESPONSIBILITIES\nGenerating robust advanced analytics and developing new cutting-edge machine learning models and data-driven tools to support our ongoing data strategy and drive future business performance;\nOptimising and evolving the current models and analytics solutions that are in production, taking a test and learn approach and ensuring improvements are impactful and aligned to business objectives and strategy;\nPresenting the analytics solutions, models and insights to a range of business stakeholders and contributing to strategic decisions;\nContributing new ideas towards improving our current solutions, processes and unsolved business problems, having the opportunity to directly feed into our data strategy agenda and roadmap;\nWorking within cross-functional teams and delivering under an agile project-based framework;\nWorking with the latest big data technologies and continuously learning and adapting in this fast-evolving space;\nBeing pro-active and staying up to date with latest trends in analytics and technology;\nPERSONAL PROFILE\nAdvanced degree, MSc or PhD in a quantitative field (e.g., Data Science, Mathematics, Statistics, Econometrics, Computer Science, Physics, Engineering etc.);\nSome experience as a Data Scientist in a commercial environment and customer focused business is an advantage;\nInterest and hands-on experience with time series, marketing mix modelling, econometrics, recommendation systems, customer journey modelling techniques or deep learning is preferred;\nProven personal portfolio of projects where analytics and data science were used to drive business value and decisions;\nStrong in problem-solving, combining both a logical and innovative appro ...
#   'metadata': 'Graduate',
#   'title': 'Data Scientist',
#   'companyInfo': 'Burberry|696 reviews|London'},
#  '41ce545464f94ca7': {'id': '41ce545464f94ca7',
#   'description': 'TikTok is the leading destination for short-form mobile video. Our mission is to inspire creativity and bring joy. TikTok has global offices including Los Angeles, New York, London, Paris, Berlin, Dubai, Mumbai, Singapore, Jakarta, Seoul and Tokyo. We are now looking for talented individuals to join us in 2022 - people who want to inspire creativity and co-create the future with TikTok.\n\nSummer Internships at TikTok aim to provide students the chance to work with our clients and teams to address key business problems and identify areas of growth for the company. With your education and experience, you will be able to take on real-world challenges from day one.\n\nThis role sits within our TikTok recommendation team. The team is responsible for developing state-of-the-art machine learning models and strategies to improve user consumption experience, inspire creativity and build a fair and flourishing ecosystem.\n\nWithin this role, you will:\n\nBuild industry-leading recommendation systems, improving user experience, content ecosystem and platform security\nDevelop state-of-the-art machine learning models to solve problems at TikTok scale\nSystematically develop product strategy with strong analytical and impact-driven mindset\nWork with TikTok cross functional teams to grow TikTok in important regional markets\nCurrently in your penultimate year pursuing a bachelors degree or in your final year going on to study a Masters, graduating in 2023\nStudying computer science, engineering or a related technical discipline\nAvailable from June for at least 12 weeks\nInterest in at least one of the following areas: machine learning, data mining, algorithms\nGreat communication and teamwork skills\nPassionate about techniques and solving challenging problems\n\n',
#   'metadata': 'Internship',
#   'title': 'Machine Learning Engineer Summer Intern (Recommendation) - 2022 Start',
#   'companyInfo': 'TikTok|38 reviews|London'},
#  'c461ed010a20c835': {'id': 'c461ed010a20c835',
#   'description': "Founded in 2013, Healios is a leading specialist digital healthcare company working to empower patients and families affected by mental health, autism and ADHD conditions to support long-term outcomes and wellbeing. Our mission is to bring exceptional healthcare to anyone, anytime, anywhere.\nHealios is pioneering the world’s first digitalisation of a NHS Mental Health Trust outpatient services, covering multiple complex specialist assessment and psychological intervention services. By digitising entire clinical pathways, we enable children, adults and their family members to receive and seamlessly transition between clinical services from the comfort of their home. By blending the best of technology, design, specialised clinical expertise and a personal human connection, Healios is transforming the experience of how care is accessed and received to help patients and families lead a better quality of life.\nWe are an organisation that empowers our staff to make a real difference not only in reshaping how mental health and neurodevelopment services are delivered across the UK, but also in the lives of those individuals and families who need our support. Our teams are friendly, focused and passionate about making a positive difference to our patients and their families.\nOur clinicians work as part of a home-based multi disciplinary team, delivering assessments, cognitive behavioural therapy and goal based interventions. Our clients benefit from being able to engage with an experienced professional team from the comfort of their own home. Healios is open from 8am to 9pm seven days a week (closed on bank holidays). This is an important part of enabling Healios clinicians to support children, young people and their families at times that work for them.\nWe are a highly motivated and energetic team bringing a wide range of talents, experience and knowledge to the service. Our clinicians have the benefit of leadership, supervision and training from experts in the field.\nAbout the role:\nWe’re looking for someone special, someone who is passionate about championing and delivering data science to support Healios in the way we deliver care and operate. You will be instrumental in leveraging the value of our data to create insight, solve complex problems and improve our clinical effectiveness; you will be familiar with diagnostic and predictive analytics. You will join a growing Business Insights team working in a fast-paced environment to deliver world-class data solutions that will have an impact on improving people’s lives within mental health, autism and ADHD conditions.\n\nResponsibilities:\nDelivering Data Science capabilities to support evidence based decision making and a data centric culture\nProposing data science solutions and strategies to tackle business challenges.\nUse Data Science to deliver actionable health and operational insights\nSupport the decision making process to select appropriate data science/analytics tools\nImplement structure, documentation and process in everything that you do, to catalyse the development of our analytics community\nBeing the subject matter expert on the selected Data Science tools; mentor colleagues in the Business Insights team to use them\nWorking closely with colleagues including the Head of Business Insights, Data Engineers, BI Analysts/Developers, Developers, Product Specialists and Machine Learning Engineers\nCollaborating across departments and internal stakeholders to understand business requirements, developing BI solutions and interpreting and communicating the outputs\n\nWhat we'll provide for you:\nA collaborative culture where curiosity, creativity, experimentation and innovation are fostered\nA highly motivated and energetic team bringing a wide range of talents, experience and knowledge to solve complex challenges\nAutonomy to help shape and design world leading clinical pathways that harness the power of combining technology with evidence-based interven ...
#   'metadata': '£55,000 - £70,000 a year| -  |Permanent',
#   'title': 'Data Scientist',
#   'companyInfo': 'Healios|London|Remote'},
#  '1fe7173e0d89af7a': {'id': '1fe7173e0d89af7a',
#   'description': "Are you a forward-thinking and aspiring undergraduate ready to take your next steps in the world of Mobility? Could this be the next exciting step on your journey to your career? If yes, start your year in industry with us at Yunex Traffic – a Siemens Business.\nOur mission is to help get people and goods to where they need to go as efficiently as possible. Our innovation in intelligent transport systems aims to both improve our current solutions and invent totally new ones for the significant challenges of tomorrow. The future of mobility is moving away from private car ownership to integrated, multi-modal transport networks. Vehicle connectivity is unlocking new opportunities for individuals, infrastructure and fleet operators alike. Click here for more information about the company.\nThe Role\nYou will spend 12 months working with our industry experts on cutting edge innovative projects to identify opportunities that support our global businesses. You'll make meaningful contributions while developing your professional expertise in a dynamic team environment.\nBased in the Innovation team, you will report directly to our software lead engineers. While day-to-day responsibilities will vary based on the nature of the project, you’ll build your foundational knowledge, professional skills, and experiences to take your career in many different directions. In your role, you’ll help to drive projects through to completion by analysing and presenting key data and improving our products & offerings. By doing this you will be supporting both our internal teams and our clients.\nEntry Requirements: For this role you must be studying towards your full BSc, MSc or PhD in Computer Science, Software Engineering, Data Analysis, or similar discipline.\nWe are looking for someone who:\nHas strong analytical and problem-solving skills.\nIs a creative thinker with great attention to detail.\nIs organised and able to work under pressure.\nIs able to learn new skills quickly through informal learning.\nIs self-motivated and able to work in a team as well as independently with minimal supervision.\nHas strong communication skills.\nTechnical knowledge required:\nHas experience using both qualitative and quantitative analysis techniques such as clustering, regression, pattern recognition, descriptive and inferential statistics.\nHas experience working on large-scale data science/data analytics projects.\nHas experience programming with Python or other programming languages.\nHas public cloud knowledge such as AWS, GCP and Azure.\nHas strong mathematical skills and MS Excel ability.\nWhat we Offer\nAt Yunex Traffic you’ll be working on exciting, world-leading engineering and innovative projects from day one. Our internship will prepare you with the skills required to support throughout your career. We will help you make the very most of your talents. We place great importance not only on what we do, but how and why we do it. We are passionate, collaborative, and take pride in work that helps our customers and communities. Working for Yunex Traffic, you’ll go home at the end of each day knowing what you do really makes a difference. you will gain an excellent and varied experience working on real projects in a leading, global, high-tech company. At Yunex Traffic you will have the opportunity to work with other interns and skilled/diverse engineers, ranging from cyber security, data and analytics, technology consultants and field operators.\nWhat else do I need to know?\nClosing Date: Applications should be received no later than 28th February 2022 for standard admissions, but later applications may be considered depending on the role remaining in place.\nDuration: The internship will begin in September 2022, and we can be flexible about the start date. The length of the internship is 12 months.\nLocation: This internship will be at our Poole office, based 2.5 miles outside Poole city centre (with frequent direct bus services). Poole ...
#   'metadata': 'Full-time, Internship',
#   'title': 'Data Scientist Intern (12 months)',
#   'companyInfo': 'Siemens|10,002 reviews|Poole BH17'},
#  'f1b98d776e72be61': {'id': 'f1b98d776e72be61',
#   'description': 'My client is a highly reputable, leading national insurance business looking to expand their team further. With a phenomenal track record of success and a prominent leader in their field, a commitment to providing a fun and supportive culture for their employees is as important as their company performance.Due to continued growth we have an exciting brand new role for a Data Scientist. This is a full time (35 hours worked flexibly), permanent role based in Truro. For the right candidate there will be a consideration for home working but please note you will need to report to the office weekly. The salary is dependent on relevant experience and qualification but you will also receive excellent benefits and a lovely working environment.If you are a numbers person with an analytical brain this role could be perfect for you.Main duties include;Produce and deliver accurate management information and business intelligenceAssist in the development and maintenance of sets of dataIdentify tools and processes that can be used to enhance business capabilitiesProduce and present technical insight and business reportsLook at ways of incorporating automation and AIThe successful candidate must have;A degree or equivalent in Maths, Statistics or similarConfident and proactive approach to workExcellent communication skillsKnowledge and experience on Data Science or Data WarehousingWorking knowledge of Power BI and PythonKnowledge and experience with AI toolsThis is a truly excellent opportunity to join a growing business offering secure and stable career prospects.Elite Staffing Solutions are acting as an Employment Agency on this vacancy.Reference ID: BH1374Job Types: Full-time, PermanentSalary: Up to £40,000.00 per yearBenefits:Work from homeSchedule:Monday to FridayWork remotely:Yes',
#   'metadata': 'Up to £40,000 a year| -  |Full-time, Permanent',
#   'title': 'Data Scientist',
#   'companyInfo': 'Elite Staffing Solutions|Truro|Remote'},
#  'ec3849d4dda665c6': {'id': 'ec3849d4dda665c6',
#   'description': 'Robert Half are currently supporting a Northampton based client looking to appoint Data Scientist on a permanent basis. We are looking to pay £45,000+ for the right candidate.\nAs Data Scientist, the main objective will be to work within the Data Analytics department to deliver reports and insights to drive the business forward and work closely with the business leaders to implement and drive process improvements across the organisation\nSupport IT function with the implementation of Data Governance /practices and processes that ensure the management of data assets and data analytics management platform\nLead the creation of Omnichannel dashboard and its evolution to become an holistic analytics insights platform reflecting\nIdentify and drive the integration of relevant internal and external data sources into the same reporting ecosystem (structured and unstructured data)\nIdentify KPIs of the various digital channels and measure the ROI\nAnalyse all marketing data in an integrated way in order to obtain useful insights for business decisions\nGenerate reporting and analysis of media activities on a weekly and monthly basis\nThe ideal candidate will have:\nA degree or relevant numerical or STEM qualification\n1 to 5 years of experience in a similar role\nExperience of working with various BI tools\nCompetent with coding languages i.e. Python, R\nThe flexibility to travel globally from time to time\nSalary banding for this role is from£45,000.\nRobert Half Ltd acts as an employment business for temporary positions and an employment agency for permanent positions. Robert Half is committed to equal opportunity and diversity. Suitable candidates with equivalent qualifications and more or less experience can apply. Rates of pay and salary ranges are dependent upon your experience, qualifications and training. If you wish to apply, please read our Privacy Notice describing how we may process, disclose and store your personal data: roberthalf.co.uk/privacy notice.',
#   'metadata': '£45,000 - £50,000 a year| -  |Permanent',
#   'title': 'Data Scientist',
#   'companyInfo': 'Robert Half|12,647 reviews|Northampton'},
#  '278142c7efa8c49a': {'id': '278142c7efa8c49a',
#   'description': "Junior Data Scientist\nHome Based working\nCompetitive Salary + Benefits\n\nSaint-Gobain - Winners of ‘TOP EMPLOYER UK AND GLOBAL' five years running! (2016-2021)\n\nSaint-Gobain is a global leader in the construction industry with a presence in over 67 countries worldwide. Our businesses designs, manufactures and distributes building materials and solutions globally.\n\nA truly exciting time to join us. This is a perfect opportunity for someone who has a passion within the field of Machine Learning and algorithms. I am looking for Junior Data Scientist, this is a home based role so you can be based anywhere within the UK, as long as you are able to come to one of our Saint-Gobain offices on an ad hoc basis. (Coventry, Newbury & Huddersfield)\n\nAs a Junior Data Scientist you will contribute towards designing and developing data science algorithms and business solutions on a project basis and work to further the progress of the data science team.\n\nWith the application of these developed and applied techniques, tools and algorithms you will make recommendations on how the business could increase profit, decrease costs and optimize workflow of SGBD UK.\n\nWhat you need to be successful\n\nThis role will suit someone who has a keen desire to learn and develop their career in Data Science. You will have a degree in numerical discipline i.e. Mathematics, Statistics, Computer Science, Physics etc. as well as previous programming experience with data on Python, R OR SQL.\n\n\nThis role could suit someone who has completed their Masters or PHD and want to get their foot into the door or someone who has been doing a Data Analytical role and wants the next step in their career as a Junior Data Scientist.\n\n\nWhat you will get in return\nCompetitive Salary.\nA defined contribution pension scheme\n33 days holiday (including bank holidays)\nFlexible Holiday buy-sell scheme (allowing up to 3 days holiday to be bought or sold).\nAs an employee you are automatically covered by the Saint-Gobain Life Assurance Scheme.\nStaff discounts on high street and leisure activities and various other benefits.\n\n\nIf you’re up for a new challenge and think you’ve got what it takes, apply online today!\nWho are we ?\nDiversity:\n\nWe are an inclusive employer and keen to hire talented people regardless of their background, abilities, ethnicity, religion, sexual orientation, gender, national origin, what football team you support, taste in music, fashion sense or anything else that makes you, you!\n\n\nWe believe that working in a diverse business can be more enjoyable, teams can be more innovative, and make better decisions. We already employ many fantastic people from diverse backgrounds, but we still want to do more.\n\n\nSo, we are on a mission to make Saint-Gobain inclusive and accessible to all, with role models for you to look up to and learn from, no matter who you are!\n\n\nAt Saint-Gobain, our purpose is to ‘Make the world a better home’. We are both manufacturers and distributors. Together with and for our customers, we design materials and solutions that have a positive impact on everyone’s life and provide well-being, quality of life and performance, while caring for the planet. Our materials can be found everywhere in our living places and daily life: in buildings, transportation, infrastructure and in many industrial applications.",
#   'metadata': 'Permanent',
#   'title': 'Junior Data Scientist',
#   'companyInfo': 'Saint-Gobain|3,409 reviews|Coventry|Remote'},
#  '8e4ebf6f8f6568f8': {'id': '8e4ebf6f8f6568f8',
#   'description': 'Pythia Sports are looking for a creative thinking and experienced person to join their established in-house modelling team as a Senior Data Scientist in modelling and simulation. The purpose of the role is to develop and conduct statistical analysis of predictive models for a sports prediction pipeline.As a Senior Data Scientist you will: Have a deep understanding of the data, its limitations and meaning, including the investigation of data validityBuild and maintain data-driven predictive modelsResearch and apply novel modelling techniquesBuild and maintain model validation metrics to regularly track performanceHave awareness of the limitations of any model outputHave an understanding of statistical robustness and validity.Key Skills / QualificationsExperience using advanced statistics and modelling techniques – preferably in sports fieldPhD or equivalent industry experience with dataStrong programming skills, with a preference for (but not limited to) Matlab, Python and RA track record of using data to solve complex problemsA knowledge and interest in sport will be helpfulExperience working with cloud computing (desirable).Right to work in the UKCandidate OverviewThe successful Data Scientist will be an innovative, self-driven person with high levels of integrity. They will be working closely with local and remote teams and therefore need to be highly communicative, but also work well independently. They must be well organised and have the ability to handle multiple projects simultaneously.Company OverviewPythia Sports is a fast growing technology company with a focus on predictive sports modelling and data collection. We focus on being the best at what we do and recognise that our success comes from having the best employees and keeping them happy. We pride ourselves on hiring talented, creative and free thinkers.Here you will find a relaxed atmosphere, monthly social events and amazing people! If working from the office, there are also free healthy snacks, fruits, coffee, tea and beer. That\'s of course once things get back to "normal" and we are back to the office a few days a week, as most of us are currently working fully from home - future home working can be considered as well.We also offer private health and dental insurance, cycle to work scheme, enhanced paternity and maternity leave, enhanced sick pay, increased holiday allowance, discretionary annual bonus and exciting development opportunities.Pythia Sports employees are expected to embrace the company philosophy of integrity combined with innovation and cutting edge technology.Job Types: Full-time, PermanentSalary: £60,000.00-£95,000.00 per yearAdditional pay:Bonus schemeBenefits:Additional leaveCasual dressCompany eventsCompany pensionCycle to work schemeFlexible schedulePrivate dental insurancePrivate medical insuranceReferral programmeSick payWork from homeSchedule:Monday to FridayCOVID-19 considerations:Most of us are currently working fully from home.Education:PhD (preferred)Work authorisation:United Kingdom (preferred)Application deadline: 15/02/2022Reference ID: Senior Data Scientist',
#   'metadata': '£60,000 - £95,000 a year| -  |Full-time, Permanent',
#   'title': 'Senior Data Scientist',
#   'companyInfo': "Pythia Sports|1 Hudson's Place, London SW1V|Temporarily remote"},
#  'c8610c368721c0ab': {'id': 'c8610c368721c0ab',
#   'description': "TikTok is the leading destination for short-form mobile video. Our mission is to inspire creativity and bring joy. TikTok has global offices including Los Angeles, New York, London, Paris, Berlin, Dubai, Singapore, Jakarta, Seoul and Tokyo.\n\nWe are looking for a passionate Data Scientist with demonstrable knowledge of product analytics, data modelling and reporting. As a Data Scientist, you will have the opportunity to influence key strategic decisions by sharing insights to leadership and business owners. You will collaborate with product managers, algorithm team, user growth, content programming and operation teams to drive insights and deliver product recommendations. Come join our team and help grow our TikTok community!\n\n\nDevelop a deep understanding of the TikTok ecosystem and business; identify key needs and pain-points and produce actionable solutions through structuring and executing product and ecosystem analyses\nHelp grow engagement and usage of TikTok through developing actionable strategic insights through product funnels, cohort analyses, user segmentation, retention analyses and regression models\nDevelop time series, forecasting, anomaly detection, and user behaviour models to solve complex product problems\nDefine KPIs and build automated dashboards, reports, and models to enable cross-functional teams to make faster, better decisions and drive constant improvement to TikTok's analytics capabilities\nCreate and manage workflows in SQL and Python/R to drive one-time or repeatable product analyses and product/ecosystem health reporting\nBA/BS in Computer Science, Math, Economics, Statistics, or other quantitative fields\n4+ years work experience doing quantitative analysis in the tech industry\nA strong track record of identifying key business questions, performing analyses, and communicating impactful findings in a clear and concise way.\nExperience in applying common statistical methods to business and product problems (design and analysis of experiments, regression modelling and forecasting)\nExperience navigating and working with very large data sets and developing large and complex data pipelines using SQL/HQL\nExperience with R or Python\nExperience with a data visualisation tool (e.g. Tableau, Looker)\nSelf-motivated, detail-oriented, learn autonomously, and highly organised\nAbility to approach problems creatively and build structure out of ambiguous requests\n\nPreferred Qualifications:\n\nAdvanced degree in Computer Science, Data Science, Statistics, Applied Math, Economics or related quantitative fields preferred\nExperience in advanced statistical methods\nBilingual English-Chinese (Mandarin) a plus\n\n",
#   'title': 'Data Scientist',
#   'companyInfo': 'TikTok|38 reviews|London'},
#  '98f78125259351fb': {'id': '98f78125259351fb',
#   'description': "About the Role\nI am the: Data Scientist\n\nI report to the: Head of Data Science\n\nPeople to help me: Club Support Team / Reporting Team / Regional & General Managers\n\nPeople I look after: N/A\n\nWorking Pattern: Mon – Fri, 9am – 5pm\n\n\nWhy would I want to be a Data Scientist at David Lloyd Clubs?\nYou want to be part of an organisation where an ever-expanding portfolio of Data Science projects drives EBITDA improvementYou are keen to encourage adoption of Data Science across the entire businessWe offer a competitive salaryWe offer remote workingWe have been ranked in the ‘Sunday Times 25 Best Big Companies To Work For' for several years runningWe have an attractive benefits package including free membership at our 123 clubs for you and your family\n\nWhat would make me the right fit for David Lloyd’s Data Science Team?\n\nYou are friendly person with strong communication skillsYou enjoy working with colleagues from across the business and empowering them through Data ScienceYou show strong initiative and have a clear sense of commercial awareness\n\nWhat will I be doing?\n\nYou will be present at all stages of the Data Science project lifecycle including:\n\nIdentifying high value opportunities and designing strategic approaches for value deliveryDeveloping machine learning and analytics solutionsConducting pilot studies to validate assumptions and inform rollout, including tracking results and presenting backDeploying processes as BAU to empower colleagues to use Data Science\n\nWhat skills do I need to have?\n\nBachelor’s degree or higher in a STEM subject, or extensive experience of applying Data Science in a commercial setting with evidence of having developed your theoretical understanding of Data ScienceComplete set of Data Science skills, including:\nAdvanced machine learning\nData engineering\nData visualisation\nStrong commercial analytics skill set\nHands-on experience working with counterparts from across all areas of the business, demonstrating a high level of autonomy and responsibilityArticulating complex Data Science concepts in simple terms to stakeholders across the business\n\nWhat else do I need to know?\n\nThis role requires a minimum of 2 days in the office, 3 at home but can be negotiated after the probation period. This is usually at our head office in Hatfield, Hertfordshire, but can occasionally be at one of our other clubs (e.g. Kensington) at the discretion of the Head of Data ScienceAt this time, we can only accept applications that DO NOT require a sponsorship to work in the UK\n\nThe contents of this job description are intended to act as a guide to the main responsibilities of this position. However, the post holder will be expected to carry out any other related duties as requested by the Group Central Membership Manager and/or the Group Experience Director and Chief Financial Officer.",
#   'metadata': 'Permanent',
#   'title': 'Data Scientist',
#   'companyInfo': 'David Lloyd Leisure|493 reviews|Hatfield|Remote'},
#  '9a36d2355241924b': {'id': '9a36d2355241924b',
#   'description': 'Pythia Sports are looking for a creative thinking and experienced person to join their established in-house modelling team as a Data Scientist in cricket modelling and simulation. The purpose of the role is to develop, and conduct statistical analysis of, human-interpretable predictive models for a cricket prediction pipeline.As a Data Scientist you will:Have a deep understanding of the data, its limitations and meaning, including the investigation of data validityUncover trends in multiple sports datasetsBuild and maintain data-driven predictive modelsResearch and apply novel modelling techniquesBuild and maintain model validation metrics to regularly track performanceHave awareness of the limitations of any model outputHave an understanding of statistical robustness and validity.Key Skills / QualificationsExperience using advanced statistics and modelling techniques – preferably in sports fieldPhD or equivalent industry experience with dataStrong programming skills, with a preference for (but not limited to) Matlab, Python and RA track record of using data to solve complex problemsA knowledge and interest in sport will be helpfulExperience working with cloud computing (desirable).Candidate OverviewThe successful Data Scientist will be an innovative, self-driven person with high levels of integrity. They will be working closely with local and remote teams and therefore need to be highly communicative, but also work well independently. They must be well organised and have the ability to handle multiple projects simultaneously.For this role, the following attributes and experience would also be a big plus:A keen interest in cricket, especially limited overs cricketPrevious experience working with cricket dataExperience working with event-based Monte Carlo simulationsCompany OverviewPythia Sports is a fast growing technology company with a focus on predictive sports modelling and data collection. We focus on being the best at what we do and recognise that our success comes from having the best employees and keeping them happy. We pride ourselves on hiring talented, creative and free thinkers.Here you will find a relaxed atmosphere, monthly social events and amazing people! If working from the office, there are also free healthy snacks, fruits, coffee, tea and beer. That\'s of course once things get back to "normal" and we are back to the office a few days a week, as most of us are currently working fully from home - future home working can be considered as well.We also offer private health and dental insurance, cycle to work scheme, enhanced paternity and maternity leave, enhanced sick pay, increased holiday allowance, discretionary annual bonus and exciting development opportunities.Pythia Sports employees are expected to embrace the company philosophy of integrity combined with innovation and cutting edge technologyJob Types: Full-time, PermanentAdditional pay:Bonus schemeBenefits:Additional leaveCasual dressCompany eventsCompany pensionCycle to work schemeFlexible schedulePrivate dental insurancePrivate medical insuranceReferral programmeSick payWellness programmesSchedule:Monday to FridayCOVID-19 considerations:Currently working from home.Application question(s):Do you have experience working with Cricket data?Education:Master\'s (preferred)Work authorisation:United Kingdom (required)Application deadline: 02/02/2022Reference ID: Cricket',
#   'metadata': 'Full-time, Permanent',
#   'title': 'Data Scientist (Cricket)',
#   'companyInfo': "Pythia Sports|1 Hudson's Place, London SW1V|Temporarily remote"},
#  'f11971796d62ded9': {'id': 'f11971796d62ded9',
#   'description': 'Data Scientist (Football) Data Scientist - FootballPythia Sports are looking for a creative thinking and experienced person to join their established in-house modelling team as a Data Scientist in football modelling and simulation. The purpose of the role is to develop and conduct statistical analysis of predictive models for a football prediction pipeline.As a Data Scientist you will:Have a deep understanding of the data, its limitations and meaning, including the investigation of data validityBuild and maintain data-driven predictive modelsResearch and apply novel modelling techniquesBuild and maintain model validation metrics to regularly track performanceHave awareness of the limitations of any model outputHave an understanding of statistical robustness and validity.Key Skills / QualificationsExperience using advanced statistics and modelling techniques – preferably in sports fieldPhD or equivalent industry experience with dataStrong programming skills, with a preference for (but not limited to) Matlab, Python and RA track record of using data to solve complex problemsA knowledge and interest in sport will be helpfulExperience working with cloud computing (desirable).Candidate OverviewThe successful Data Scientist will be an innovative, self-driven person with high levels of integrity. They will be working closely with local and remote teams and therefore need to be highly communicative, but also work well independently. They must be well organised and have the ability to handle multiple projects simultaneously.Company OverviewPythia Sports is a fast growing technology company with a focus on predictive sports modelling and data collection. We focus on being the best at what we do and recognise that our success comes from having the best employees and keeping them happy. We pride ourselves on hiring talented, creative and free thinkers.Here you will find a relaxed atmosphere, monthly social events and amazing people! If working from the office, there are also free healthy snacks, fruits, coffee, tea and beer. That\'s of course once things get back to "normal" and we are back to the office a few days a week, as most of us are currently working fully from home - future home working can be considered as well.We also offer private health and dental insurance, cycle to work scheme, enhanced paternity and maternity leave, enhanced sick pay, increased holiday allowance, discretionary annual bonus and exciting development opportunities.Pythia Sports employees are expected to embrace the company philosophy of integrity combined with innovation and cutting edge technologyJob Types: Full-time, PermanentAdditional pay:Bonus schemeBenefits:Additional leaveCasual dressCompany eventsCompany pensionCycle to work schemeFlexible schedulePrivate dental insurancePrivate medical insuranceReferral programmeSick payWork from homeSchedule:Monday to FridayCOVID-19 considerations:We are currently working from home and expected to start attending office once a week in the next few months.Application question(s):DO you have experience with sports data modelling?Education:Master\'s (preferred)Work authorisation:United Kingdom (required)Reference ID: Football',
#   'metadata': 'Full-time, Permanent',
#   'title': 'Data Scientist (Football)',
#   'companyInfo': "Pythia Sports|1 Hudson's Place, London SW1V|Temporarily remote"},
#  '1619eda6ee3dcbb0': {'id': '1619eda6ee3dcbb0',
#   'description': "Are you passionate about Facebook’s product, analytics and technology? The Analytics team is looking for fast-moving analytics candidates and data junkies who want to make an impact. Candidates will help own analytics for a particular product or business at Facebook and work with product managers and engineers to translate the analysis into meaningful impact to the business. Please note that candidates will have a general interview and then we will make a determination of actual team assignments.\n\n\nPerform large-scale data analysis and develop effective statistical models for segmentation, classification, optimization, time series, etc.\nDesign and implement reporting dashboards that track key business metrics and provide actionable insights\nIdentify actionable insights, suggest recommendations and influence the direction of the business by effectively communicating results to cross-functional groups\nWork closely with Product or Engineering & Operations teams to proactively create rule and manage decisions\nPrioritize leads so that the teams work on the most valuable cases\nSuggest improvements in the tools and techniques to help scale the team\n\n\nCurrently has, or is in the process of obtaining, a Bachelors or Masters degree in Computer Science, Mathematics, Economics, Statistics or related technical field\nExperience utilizing both qualitative analysis (e.g., content analysis, phenomenology, hypothesis testing) and quantitative analysis techniques (e.g., clustering, regression, pattern recognition, descriptive and inferential statistics)\nExperience in presenting qualitative and quantitative data\nMust obtain work authorization in country of employment at the time of hire, and maintain ongoing work authorization during employment\n\n\nExperience as a Programmer - Python, Perl, Java, and/or C++\nExperience in collaborating with individuals and organizations\nInternship experience in solving analytical problems using quantitative approaches\n\n\nFacebook's mission is to give people the power to build community and bring the world closer together. Through our family of apps and services, we're building a different kind of company that connects billions of people around the world, gives them ways to share what matters most to them, and helps bring people closer together. Whether we're creating new products or helping a small business expand its reach, people at Facebook are builders at heart. Our global teams are constantly iterating, solving problems, and working together to empower people around the world to build community and connect in meaningful ways. Together, we can help people build stronger communities - we're just getting started.",
#   'title': 'Data Scientist, Analytics (University Graduate)',
#   'companyInfo': 'Facebook App|642 reviews|London'},
#  '14a3bb31248f543a': {'id': '14a3bb31248f543a',
#   'description': 'TikTok is the leading destination for short-form mobile video. Our mission is to inspire creativity and bring joy. TikTok has global offices including Los Angeles, New York, London, Paris, Berlin, Dubai, Mumbai, Singapore, Jakarta, Seoul and Tokyo. We are now looking for talented individuals to join us in 2022 - people who want to inspire creativity and co-create the future with TikTok.\n\nRegardless of the function you choose to specialise in, our graduate roles will enable you to participate in meaningful and innovative projects. Your potential for growth at TikTok is limitless. Join us to enhance your skill set and develop your network in the tech industry.\n\nThis role sits within our TikTok recommendation team. The team is responsible for developing state-of-the-art machine learning models and strategies to improve user consumption experience, inspire creativity and build a fair and flourishing ecosystem.\n\nWithin this role, you will:\n\nBuild industry-leading recommendation systems, improving user experience, content ecosystem and platform security\nDevelop state-of-the-art machine learning models to solve problems at TikTok scale\nSystematically develop product strategy with strong analytical and impact-driven mindset\nWork with TikTok cross functional teams to grow TikTok in important regional markets\nCurrently enrolled in a Bachelors or Masters degree, graduating in 2022\nStudying computer science, engineering or a related technical discipline\nInterest in at least one of the following areas: machine learning, data mining, algorithms\nGreat communication and teamwork skills\nPassionate about techniques and solving challenging problems\n\n',
#   'title': 'Machine Learning Engineer Graduate (Recommendation) - 2022 Start',
#   'companyInfo': 'TikTok|38 reviews|London'},
#  'e7d30ae416f248ca': {'id': 'e7d30ae416f248ca',
# ...
#   'metadata': '£36,694 - £49,210 a year| -  |Full-time, Fixed term',
#   'title': 'Research Assistant / Associate in Physics-aware machine learning for exascale fluid mechanics',
#   'companyInfo': 'Imperial College London|167 reviews|South Kensington'},
#  '8a2499edf3537ed3': {'id': '8a2499edf3537ed3',
#   'description': 'Job Title: Data Engineer / Data Scientist\nLocation: Crewe – CW1 6BD\nRadius Payment Solutions is a diversified supplier of fuel cards, vehicle-tracking, telecoms, insurance and other key business services to companies of all sizes worldwide. We are a successful, fast-growing global company with offices across five continents.\nAs an industry leading payment solutions provider, we are seeking an experienced, motivated, and focussed Data Engineer to join our Data Science team in Marketing. The aim of the Data Science team is to empower all Radius divisions with smart insights to drive strategy and decision-making in Marketing and Sales operations. We aim to deliver such insights through deploying predictive and propensity models, segmentation analysis, etc.\nWe are looking for an experienced Data Engineer who will help build, deploy, and maintain Machine Learning models across different systems and data environments. The ideal Data Engineer would be curious about data and creative in deriving insights and features for Machine Learning models. The role will report to the Head of Commercial and will be primarily located at the group’s head office in Crewe with some remote work.\nKey Responsibilities:\n Typical work activities will include:\nDesign and develop efficient architecture for different data pipelines and models\nInvestigate and explore a wide array of data sources within Radius to find and share beneficial insights\nHelp build complex algorithms and predictive models that aid strategic decision-making and provide unique insights into data\nCollaborate across teams, divisions, and geographies\nWhat experience / skills we are looking for?\n2+ years of experience with Python and SQL for Data Engineering and Data Science\nUnderstanding of statistical and Machine Learning models\nProficient in data visualization/exploration tools\nAbility to problem solve and design solutions for complex systems\nAbility to communicate effectively across organisational and technical boundaries\nGood documentation, organisation, and time-management skills\nWhy choose Radius?24th in the Sunday Times HSBC Top Track 100 list of Britain’s largest privately owned companiesInternal talent development programmeSecondment opportunities to work in our overseas officesInnovative, technology driven cultureRapidly expanding global company with an entrepreneurial mindset\nWhat benefits do we offer?Annual salary reviews;22 days holiday plus bank holidays (increasing with each year of services to a maximum of 25);Company sick pay, life assurance and pension;Newly built Global Headquarters with onsite gym, break out rooms and canteen. Other facilities include PlayStation 4, table tennis and pool table;Fantastic opportunities for ongoing development and progression;Plus more benefits…\nIf you would like any further information about this role, please contact Melanie on +441270 667668\nRadius Payment Solutions has an in-house recruitment team who are dedicated to sourcing candidates directly and as such we do not accept speculative CVs from agencies.\nAnalytics / data analysis / marketing / data science data scientist Python SQL ML Machine Learning Algorithms visualisation',
#   'metadata': 'Full-time',
#   'title': 'Data Engineer / Data Scientist',
#   'companyInfo': 'Radius Payment Solutions|77 reviews|Crewe CW1'},
#  '8559534d87a73b1b': {'id': '8559534d87a73b1b',
#   'description': "Who we are:\n\nArtefact is a new generation of a data service provider, specialising in data consulting and data-driven digital marketing, dedicated to transforming data into business impact across the entire value chain of organisations. We are proud to say we're enjoying skyrocketing growth.\n\nOur broad range of data-driven solutions in data consulting and digital marketing are designed to meet our clients' specific needs, always conceived with a business-centric approach and delivered with tangible results. Our data-driven services are built upon the deep AI expertise we've acquired with our 1000+ client base around the globe.\n\nWe have 1000 employees across 20 offices who are focused on accelerating digital transformation. Thanks to a unique mix of company assets: State of the art data technologies, lean AI agile methodologies for fast delivery, and cohesive teams of the finest business consultants, data analysts, data scientists, data engineers, and digital experts, all dedicated to bringing extra value to every client.\n\nRole Profile:\n\nA Data Scientist at Artefact will innovate, build, train and communicate with a team made up of consultants, data scientists, and engineers to identify client needs and define innovative solutions. You will work in a collaborative team which champions knowledge sharing. You will coach others, keep abreast of industry news/updates and, and share your discoveries with others.\n\nProjects you might work on:\nEvaluate optimal marketing campaign strategies using causal frameworks\nCausally measure the impact of a marketing campaign on ROI\nForecast sales using a mixture of proprietary client data and third party data\nBuild robust data pipelines on the main cloud providers (GCP, AWS, Azure)\nImplement cutting edge research\nYour technical skills:\nProgramming skills in Python including building, testing and releasing code into production\nSolid foundation in statistics or econometrics to work on projects that need: forecasting, NLP, Bayesian inference, causal frameworks, time series, hypothesis testing.\nWorking knowledge of well-known Python libraries for data and ML: pandas, numpy, scikitlearn, matplotlib. Knowing (or willingness to learn) pystan, bnlearn, pymc3 would be a bonus.\nExperience using Git and version controlling\nExperience evolving in *nix environments using the command line\nWillingness to learn and find solutions to complex problems\nSQL skills and experience working with relational/columnar databases (e.g. BigQuery, SQL Server, Postgres)\nExperience using one of the main cloud providers (GCP, Azure, AWS) is desirable\nExperience with agile software delivery and CI/CD processes is desirable\nYour mindset:\nCurious, you are always seeking innovative solutions for your clients\nSharing of knowledge is essential for you and you actively participate in the diffusion of information within Artefact (seminaries, formations, certifications)\nEntrepreneurial, you bring solutions, new ideas, within your team at Artefact\nYou are eager to work or learn on any part of the value chain of projects (infrastructures and platforms creation, data collection, application of machine learning models, APIs REST creations, of front-ends, of tests, continuous deployments)\nYou have strong communication skills and can popularize technical terms or solutions to more business oriented profiles, you can work in a team with very diversified profiles\nYou are independent in managing your tasks and timelines\nWhy join us:\nArtefact is the place to be: come and build the future of marketing\nProgress: every day offers new challenges and new opportunities to learn\nCulture: join the best team you could ever imagine\nEntrepreneurship: you will be joining a team of driven entrepreneurs. We won't give up until we make a huge dent in this industry!\n\nCome join us!",
#   'title': 'Data Scientist',
#   'companyInfo': 'Artefact|London'},
#  'e03f26755ef68608': {'id': 'e03f26755ef68608',
#   'description': 'Coders Connect are proud to be partnering with Qureight\nAbout Qureight\n\nQureight is a MedTech company based in Cambridge, UK. It was founded by medical doctors in 2018. Our mission is to combine platform technology and life sciences to generate new insight and transform the way we use clinical data to improve the lives of patients with complex diseases.\n\n\nQureight utilises AI and Machine Learning technology to curate and analyse clinical imaging data to better understand complex heart and lung diseases which allows bio-pharma and academic institutions to obtain new insights into diseases and response to treatment.\n\n\nMachine Learning Engineer\n\nWe are building a cloud-based platform which allows clients to upload, curate and analyse their data using advanced ML techniques. We are looking for experienced developers to help design, implement and deploy our platform, REST APIs and web-based UI. The role will involve working with Python and AI frameworks, model research, contributing to publications and integration of models into a production quality platform. You will be able to work with other AI experts and feel at home working with cloud-based software stack.\n\n\nRole\n\nApplication of deep learning algorithms, deep image processing and/or machine learning\n\nProficiency in Deep Learning Frameworks (Pytorch, Tensorflow, Monai etc). Specific knowledge of image segmentation using CNNs.\n\nProgramming in C/C++, Python middleware (Flask/Django), Javascript (server-side or client-side)\n\nMedical imaging, DICOM, ITK / SimpleITK / VTK\n\nHere are some signs you might love to work with us:\n\nYou are excited to work in an innovative start-up in one of the most exciting cities in the world\n\nYou enjoy working with a multidisciplinary team and collaborating with your colleagues\n\nYou can work independently to drive projects to completion\n\nYou want to work in a company who wants to make a real difference in people’s lives\nRequirements\nMinimum Requirements\n\nMinimum MSC or PHD in Machine Learning\n\n2 years commercial or Post Doc experience\n\nMedical Imaging experience or exposure\n\nFull right to work in the UK without restriction, time limit, or sponsorship\n\nProduce maintainable, testable, documented, production-grade code Strong written and verbal communication skills\n\nData science, AI, deep learning or machine learning experience either through your job or personal interest, for example Coursera, Udemy or fast.ai courses Data science, AI, deep learning or machine learning experience either through your job or personal interest, for example Coursera, Udemy or fast.ai courses\n\nPreferred skills and experience\n\nComfortable with Linux-based operating systems\n\nExperience with git\n\nSoftware design and peer code review skills\n\nExperience with automated testing and test-driven development in Python\n\nUnderstanding of time, RAM, and I/O scalability aspects of data science applications (e.g., CPU and GPU acceleration, operations on sparse arrays, model serialization and caching)\n\nExperience of working in a team using agile methodologies\n\nHave used CI and deployed infrastructure as code (e.g., terraform)\nBenefits\nWhat can we offer you?\n\nFlexible working hours\n\nRemote working possibilities for part of the week\n\n25 days annual leave, plus bank holidays\n\nContributory pension\n\nBeautiful office in the heart of Cambridge (1 min from station)\n\nOpportunities for personal development and academic collaborations in a vibrant and fast-acting company\n\nOpportunities for personal and professional development as we rapidly scale the company\n\nThe chance to join a friendly, motivated group of people on a mission for universal good in healthcare\n\nExperience in a highly regulated industry where high-quality code is a must\n\nDiscretionary employee share options scheme\n\nMinimum Requirements Minimum MSC or PHD in Machine Learning 2 years commercial or Post Doc experience Medical Imaging exp ...
#   'metadata': '£70,000 - £90,000 a year',
#   'title': 'Machine Learning Engineer',
#   'companyInfo': 'Coders Connect|Cambridge CB21|Remote'},
#  'b76b8725cff2dfa5': {'id': 'b76b8725cff2dfa5',
#   'description': "At Shift Technology, we're transforming insurance with AI. We help insurers fully automate more claims, deliver a great customer experience while protecting against risk and accurately identifying suspected fraud, making internal teams more effective and improving financial performance.\n\nSince our launch in 2014 in Paris, we've raised over $320M with Tier 1 investors, opened offices in Boston, Tokyo, Singapore, London, Madrid, Mexico, Hong-Kong, and Sao Paulo, and currently work with more than 80 of the world's leading insurers. If you are excited about joining a fast-growing insurtech innovator with a passion for excellence and global culture, Shift is the place for you.\n\nShift Technology offers a unique opportunity to brilliant candidates to accelerate their careers in data science\n\nData scientists work on a broad range of subjects, acquiring a lot of technical and professional experience in data science, data engineering, coding, business understanding and client interactions; skills invaluable in any career.\nOur company is small enough that each person's achievements have an impact on overall performance, yet big enough to be a world leader in our domain.\nWe are a fast growing company, the best contributors will grow to managerial or product tech lead positions much more rapidly than in bigger companies\n\nYOUR ROLE\n\nThe data science team is in charge of technically delivering the Shift products to clients, the key role in the success of our projects with clients. It is a hands-on job, expect to be doing everything you can imagine from the technical side in an AI company:\n\nImplementation of the data engineering, usually from client extracts to the insertion of the data in our data stores (SQL, ElasticSearch)\nDeveloping, testing, tuning models and putting them in production for tasks such as fraud detection and automation detection in complex environments.\nAutomate key business tasks by implementing them in our production process framework in C#\nConduct meetings with clients and interact with external stakeholders, whether it is direct user feedback, presenting business cases or defining the roadmap of evolutions for that client\n\nYou will actively participate in the definition and development of our suite of products on fraud detection, anti-money laundering and claim automation, working on various data types such as structured data, free text, documents and images.\n\nWHAT WE ARE LOOKING FOR\n\nAs a result of the range of the role, we are looking for people with diverse skills and proficiencies to help make our customers successful. We are open to people not having exactly all of the required skills, but in each one of those they must be willing to build expertise, and in particular we expect the following:\n\nCode-savvy, either by having a degree in computer science and/or having developed some apps with actual users, or by willing to spend a lot of time practicing. Writing scripts for models and notebooks is not enough at Shift, we thrive on people who can write maintainable, production-quality code that will run everyday without breaking.\nAI-savvy, either by having a degree in machine learning and/or statistics or be looking to work on those subjects. Having a clear understanding of statistics and machine learning problems, tasks and common resolutions is important to communicate internally and explain to the client how the product is working.\nClient facing. You will need to be comfortable, clear and professional when talking to clients during meetings and by email. Expect to talk with a client every other day and grow your communicational and presentational skills!\nBusiness smart. We don't expect candidates to know the insurance sector, but we want people who can learn and master the business aspects of our products\nFluent English speakers. We are an international company with offices in many countries and 40+ nationalities, the Shift working language is English.\nYou are based in ...
#   'title': 'Data Scientist - UK',
#   'companyInfo': 'Shift Technology|London'}}

# %%
# with open('jobs_indeed_uk.pickle', 'wb') as handle:
#    pickle.dump(jobs, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# Load data
# with open('jobs_indeed_usa.pickle', 'rb') as handle:
#    unserialized_data = pickle.load(handle)
#
# unserialized_data
